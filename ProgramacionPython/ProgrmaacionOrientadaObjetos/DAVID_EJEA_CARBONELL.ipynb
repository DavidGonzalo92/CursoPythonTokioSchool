# %% [markdown]
# # Ejercicios Modulo 3. Clases y objetos (Soluciones)
#
# Consideraciones a tener en cuenta:
#
# * Guardar este documento con el siguiente formato para su entrega: __M3_nombre_apellido1_apellido2__
# * Realizar los ejercicios con las herramientas vistas en las sesiones.
# * Comentar el código
# * Utilizar nombres de variables apropiados, si vais a guardar una nota, llamar a esa variable nota, no n o x

# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# #### Creación
#
# * Crea una clase llamada __Alumno__ que tenga los atributos nombre y nota
# * Crea el __constructor__ de la clase. Añadir en el constructor un print para informar de que el alumno se ha creado con éxito
# * Sobreescribe el método **string (``__str__``)**, para que al imprimir por pantalla se vea su informacion
# * Crear un método llamado __calificacion__ que imprima por pantalla si el alumno ha aprobado o suspendido en base a su nota
#
# #### Experimentación
#
# * Crea algunos alumnos
# * Prueba a mostrar los objetos alumno y el método calificacion

# %%
# nota hubiera sido bastante mejor usar super en la mayoria de los ejercicios

class alumno():
        pass
        def __init__(self,nombre,nota):
          self.nombre=nombre
          self.nota=nota
          print('alumno creado con exito')
        def informacion(self):
          return '{} ha sacado un {}'.format(self.nombre,self.nota)
        def calificacion(self):
            if self.nota>=5:
               return 'ha aprobado'
            else:
               return 'ha suspendido'
alumno1=alumno('david',7)
print(alumno1.informacion()+', '+alumno1.calificacion() )
# Out:
# alumno creado con exito
# david ha sacado un 7, ha aprobado

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# #### Creación
#
# Sobre el ejercicio anterior realizar la siguiente modificación.
#
# Si en el ejercicio hacemos un print(alumno1.nota) esto nos devolverá la nota del alumno. Esto puede llegar a ser un problema de seguridad, vamos a encapsular el código para que no podamos acceder directamente a las variables, y el acceso tenga que ser a través de métodos.
#
# * Hacer que las variables de la clase sean __privadas__. Recordatorio: Añadir doble guion delante del nombre de la variable
# * Crea métodos __getter y setter__ para poder acceder y modificar las variables de la clase
#
# #### Experimentación
#
# * Crea algunos alumnos
# * Comprueba que solo podamos acceder a las variables de la clase a través de sus métodos get y set

# %%
# Realizar el ejercicio aquí


class alumno_privada():
        pass
        def __init__(self,nombre,nota):
          self.__nombre=nombre
          self.__nota=nota
          print('alumno creado con exito')

        def get_nombre(self):
            return self.__nombre
        def get_nota(self):
            return self.__nota

        def set_nombre(self):
            self.__nombre=nombre
        def set_nota(self):
            self.__nota=nota

        def get_informacion(self):
          return '{} ha sacado un {}'.format(self.__nombre,self.__nota)

        def get_calificacion(self):
            if self.__nota>=5:
               return 'ha aprobado'
            else:
               return 'ha suspendido'
alumno1=alumno_privada('david',7)
print(alumno1.get_informacion()+', '+alumno1.get_calificacion() )
# Out:
# alumno creado con exito
# david ha sacado un 7, ha aprobado

# %% [markdown]
# # Ejercicio 3

# %% [markdown]
# #### Creación
#
# * Crea una clase llamada __Producto__ que tenga los atributos codigo, nombre, precio y tipo.
# * Crea el __constructor__ de la clase. Añadir en el constructor un print para informar de que el producto se ha creado con éxito
# * Crea métodos __getter y setter__ para acceder y modificar todos los atributos de la clase
#
# #### Experimentación
#
# * Crea algunos productos
# * Prueba estos nuevos métodos que se han creado (getter y setter)

# %%
# Realizar el ejercicio aquí

class producto():
        pass
        def __init__(self,codigo,nombre,precio,tipo):
          self.__codigo=codigo
          self.__nombre=nombre
          self.__precio=precio
          self.__tipo=tipo
          
          print('producto creado con exito')

        def get_codigo(self):
            return self.__codigo
        def get_nombre(self):
            return self.__nombre
        def get_precio(self):
            return self.__precio
        def get_tipo(self):
            return self.__tipo

        def set_codigo(self,codigo):
            self.__codigo=codigo
        def set_nombre(self,nombre):
            self.__nombre=nombre
        def set_precio(self,precio):
            self.__precio=precio
        def set_tipo(self,tipo):
            self.__tipo=tipo

producto1=producto(3456,'lampara',30,'metalico')
print(producto1.get_nombre())
producto1.set_nombre('bombilla')
print(producto1.get_nombre())
# Out:
# producto creado con exito
# lampara
# bombilla

# %% [markdown]
# # Ejercicio 4

# %% [markdown]
# #### Creación
#
# Ampliemos el ejercicio anterior:
# Copia todo el código que ya tengas y añade lo siguiente:
#
# * Sobreescribe el método **string (``__str__``)**, para que al imprimir por pantalla un producto y muestre todos los datos de dicho producto. Ejemplo:
#
# <img src="./Ejemplo_ej2.PNG"  />
#
# * Crear un método llamado __calcular_total__ el cual reciba un número de unidades para ese producto, y en base a ello calcule el precio total de ese conjunto de productos. Ejemplo: 5 unidades del producto 1
#
# #### Experimentación
#
# * Prueba estos nuevos métodos que se han creado

# %%
# Realizar el ejercicio aquí
class producto():
        pass
        def __init__(self,codigo,nombre,precio,tipo):
          self.__codigo=codigo
          self.__nombre=nombre
          self.__precio=precio
          self.__tipo=tipo
          
          print('producto creado con exito')

        def get_codigo(self):
            return self.__codigo
        def get_nombre(self):
            return self.__nombre
        def get_precio(self):
            return self.__precio
        def get_tipo(self):
            return self.__tipo
        def get_diccionario(self):
            return 'producto con el codigo '+str(self.__codigo)+':'+'\n nombre:'+self.__nombre+'\n precio:'+str(self.__precio)+'\n tipo:'+self.__tipo
        def get_calcular_total(self):
             return 'el precio total es:'+str(int(input('cuanto quieres del producto '+self.__nombre))*self.__precio)
             

        def set_codigo(self,codigo):
            self.__codigo=codigo
        def set_nombre(self,nombre):
            self.__nombre=nombre
        def set_precio(self,precio):
            self.__precio=precio
        def set_tipo(self,tipo):
            self.__tipo=tipo

producto1=producto(1,'lampara',30,'iluminacion')
producto2=producto(2,'bombilla',15,'ilumiacion')
producto3=producto(3,'ladron',7,'electrico')


print(producto1.get_diccionario())
print(producto1.get_calcular_total())
# Out:
# producto creado con exito
# producto creado con exito
# producto creado con exito
# producto con el codigo 1:
#  nombre:lampara
#  precio:30
#  tipo:iluminacion
# el precio total es:150

# %% [markdown]
# # Ejercicio 5

# %% [markdown]
# #### Creación
#
# Sigamos ampliando el ejercicio anterior:
# Copia todo el código que ya tengas y añade lo siguiente:
#
# * Crea una clase llamada __Pedido__ que tenga los atributos: una lista de productos y una lista de cantidades
# * Crea el __constructor__ de la clase. Añadir en el constructor un print para informar de que el pedido se ha creado con éxito
# * Crea el método __total_pedido__ el cual devuelva el importe total de un pedido
# * Crea el método __mostrar_pedido__ el cual muestra todos los productos y cantidades que componen el pedido
#
# #### Experimentación
#
# * Crea algunos pedidos
# * Prueba estos nuevos métodos que se han creado

# %%
# Realizar el ejercicio aquí
class producto():
        def __init__(self,codigo,nombre,precio,tipo):
          self.__codigo=codigo
          self.__nombre=nombre
          self.__precio=precio
          self.__tipo=tipo
          catalogo.append(self.__nombre)
          precio2.append(self.__precio)
          print('producto creado con exito')

        def get_codigo(self):
            return self.__codigo
        def get_nombre(self):
            return self.__nombre
        def get_precio(self):
            return self.__precio
        def get_tipo(self):
            return self.__tipo
        def get_diccionario(self):
            return 'producto con el codigo '+str(self.__codigo)+':'+'\n nombre:'+self.__nombre+'\n precio:'+str(self.__precio)+'\n tipo:'+self.__tipo
     
             

        def set_codigo(self,codigo):
            self.__codigo=codigo
        def set_nombre(self,nombre):
            self.__nombre=nombre
        def set_precio(self,precio):
            self.__precio=precio
        def set_tipo(self,tipo):
            self.__tipo=tipo

class pedido():
    def __init__(self):
           validacion=input('quieres comprar di si o no')
           while validacion=='si':
                print('aqui tienes el catalogo:')
                print(catalogo)
                compra=input('que quieres comprar')
                while compra not in catalogo:
                    compra=input('introducec bien el nombre:')
                lista_producto.append(compra)    
                lista_cantidad.append(input('cantidad'))
                validacion=input('quieres comprar mas')
    def mostrar_pedido(self):
          for i in range(0,len(lista_producto)):
            print('el pedido es : \n'+lista_producto[i] +': '+lista_cantidad[i])
    def total_pedido(self):
          b=0
          for i in range(0,len(lista_producto)):
            a=int(precio2[catalogo.index(lista_producto[i])])*int(lista_cantidad[i])
            b+=a
            return 'importe total es: '+ str(b)     

catalogo=[]
precio2=[]
lista_producto=[]
lista_cantidad=[]
producto1=producto(1,'lampara',30,'iluminacion')
producto2=producto(2,'bombilla',15,'ilumiacion')
producto3=producto(3,'ladron',7,'electrico')

test=pedido()
test.mostrar_pedido()
test.total_pedido()
# Out:
# producto creado con exito
# producto creado con exito
# producto creado con exito
# aqui tienes el catalogo:
# [&#39;lampara&#39;, &#39;bombilla&#39;, &#39;ladron&#39;]
# el pedido es :
# lampara: 7
# &#39;importe total es: 210&#39;

# %% [markdown]
# # Ejercicio 6

# %% [markdown]
# **Ejercicio de puntos, coordenadas y vectores sobre el plano cartesiano. A continuación los conceptos básicos.**
#
# ### El plano cartesiano
#
# Representa un espacio bidimensional (en 2 dimensiones), formado por dos rectas perpendiculares, una horizontal y otra vertical que se cortan en un punto. La recta horizontal se denomina eje de las abscisas o **eje X**, mientras que la vertical recibe el nombre de eje de las ordenadas o simplemente **eje Y**. En cuanto al punto donde se cortan, se conoce como el **punto de origen O**.
# **El plano se divide en 4 cuadrantes.**
#
# <img src="./Ejes.png"  />
#
#
#
# ### Puntos y coordenadas
#
# El objetivo de todo esto es describir la posición de **puntos** sobre el plano en forma de **coordenadas**, que se forman asociando el valor del eje de las X (horizontal) con el valor del eje Y (vertical).
#
# La representación de un punto es sencilla: **P(X,Y)** dónde X y la Y son la distancia horizontal (izquierda o derecha) y vertical (arriba o abajo) respectivamente, utilizando como referencia el punto de origen (0,0), justo en el centro del plano.
#
# <img src="./Puntos.png"  />
#
#
# ### Vectores en el plano
#
# Finalmente, un vector en el plano hace referencia a un segmento orientado, generado a partir de dos puntos distintos.
#
# A efectos prácticos no deja de ser una línea formada desde un punto inicial en dirección a otro punto final, por lo que se entiende que un vector tiene longitud y dirección/sentido.
#
# <img src="./Vector.png"  />
#
#
# En esta figura, podemos observar dos puntos A y B que podríamos definir de la siguiente forma:
# * **A(x1, y1)** => **A(2, 3)**
# * **B(x2, y2)** => **B(7, 5)**
#
# Y el vector se representaría como la diferencia entre las coordenadas del segundo punto respecto al primero (el segundo menos el primero):
# * **AB = (x2-x1, y2-y1)** => **(7-2, 5-3)** => **(5,2)**
#
# Lo que en definitiva no deja de ser: 5 a la derecha y 2 arriba.

# %% [markdown]
# #### Creación
#
# * Crea una clase llamada **Punto** con sus dos coordenadas X e Y.
# * Añade un método **constructor** para crear puntos fácilmente. Si no se reciben una coordenada, su valor será cero.
# * Sobreescribe el método **string (``__str__``)**, para que al imprimir por pantalla un punto aparezca en formato (X,Y)
# * Añade un método llamado **cuadrante** que indique a qué cuadrante pertenece el punto, o si es el origen.
# * Añade un método llamado **vector**, que tome otro punto y calcule el vector resultante entre los dos puntos.
# * Añade un método llamado **distancia**, que tome otro punto y calcule la distancia entre los dos puntos y la muestre por pantalla. La fórmula es la siguiente:
#
# <img src="./Distancia.png"  />
# <img src="./Distancia_formula.png"  />
#
# *Nota: La función raíz cuadrada en Python sqrt() se debe importar del módulo math y utilizarla de la siguiente forma:*
# ```python
# import math
# math.sqrt(9)
# > 3.0
# ```
#
# * Crea una clase llamada **Rectangulo** con dos puntos (inicial y final) que formarán la diagonal del rectángulo.
# * Añade un método **constructor** para crear ambos puntos fácilmente, si no se envían se crearán dos puntos en el origen por defecto.
# * Añade al rectángulo un método llamado **base** que muestre la base.
# * Añade al rectángulo un método llamado **altura** que muestre la altura.
# * Añade al rectángulo un método llamado **area** que muestre el area.
#
# *Puedes identificar fácilmente estos valores si intentas dibujar el cuadrado a partir de su  diagonal. Si andas perdido, prueba a dibujarlo en un papel, ¡seguro que lo verás mucho más claro! Además recuerda que puedes utilizar la función **abs()** para saber el valor absolute de un número.*
#
# #### Experimentación
# * Crea los puntos A(2, 3),  B(5,5), C(-3, -1) y D(0,0) e imprimelos por pantalla.
# * Consulta a que cuadrante pertenecen el punto A, C y D.
# * Consulta los vectores AB y BA.
# * Consulta la distancia entre los puntos 'A y B' y 'B y A'.
# * Determina cual de los 3 puntos A, B o C, se encuentra más lejos del origen, punto (0,0).
# * Crea un rectángulo utilizando los puntos A y B.
# * Consulta la base, altura y área del rectángulo.

# %%
# Realizar el ejercicio aquí
import math
#nota: este me lo encontre cuando buscaba por internet dudas, lo digo porque no me gusta llevarme el merito de nada lo que hecho, lo entendi y era tonteria cambiarlo, los demas si qu estan hechos totalmente por mi y este esta entendido
class Punto:

    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y

    def __str__(self):
        return "({}, {})".format(self.x, self.y)

    def cuadrante(self):
        if self.x > 0 and self.y > 0:
            print("{} pertenece al primer cuadrante".format(self))
        elif self.x < 0 and self.y > 0:
            print("{} pertenece al segundo cuadrante".format(self))
        elif self.x < 0 and self.y < 0:
            print("{} pertenece al tercer cuadrante".format(self))
        elif self.x > 0 and self.y < 0:
            print("{} pertenece al cuarto cuadrante".format(self))
        elif self.x != 0 and self.y == 0:
            print("{} se sitúa sobre el eje X".format(self))
        elif self.x == 0 and self.y != 0:
            print("{} se sitúa sobre el eje Y".format(self))
        else:
            print("{} se encuentra sobre el origen".format(self))

    def vector(self, p):
        print("El vector entre {} y {} es ({}, {})".format(
            self, p, p.x - self.x, p.y - self.y) )

    def distancia(self, p):
        d = math.sqrt( (p.x - self.x)**2 + (p.y - self.y)**2 )
        print("La distancia entre los puntos {} y {} es {}".format(
            self, p, d))


class Rectangulo:

    def __init__(self, pInicial=Punto(), pFinal=Punto()):
        self.pInicial = pInicial
        self.pFinal = pFinal

    
        self.vBase = abs(self.pFinal.x - self.pInicial.x)
        self.vAltura = abs(self.pFinal.y - self.pInicial.y)
        self.vArea = self.vBase * self.vAltura

    def base(self):
        print("La base del rectángulo es {}".format( self.vBase ) )

    def altura(self):
        print("La altura del rectángulo es {}".format( self.vAltura ) )

    def area(self):
        print("El área del rectángulo es {}".format( self.vArea ) )


A = Punto(2,3)
B = Punto(5,5)
C = Punto(-3, -1)
D = Punto(0,0)

A.cuadrante()
C.cuadrante()
D.cuadrante()

A.vector(B)
B.vector(A)

A.distancia(B)
B.distancia(A)

A.distancia(D)
B.distancia(D)
C.distancia(D)

R = Rectangulo(A, B)
R.base()
R.altura()
R.area()
# Out:
# (2, 3) pertenece al primer cuadrante
# (-3, -1) pertenece al tercer cuadrante
# (0, 0) se encuentra sobre el origen
# El vector entre (2, 3) y (5, 5) es (3, 2)
# El vector entre (5, 5) y (2, 3) es (-3, -2)
# La distancia entre los puntos (2, 3) y (5, 5) es 3.605551275463989
# La distancia entre los puntos (5, 5) y (2, 3) es 3.605551275463989
# La distancia entre los puntos (2, 3) y (0, 0) es 3.605551275463989
# La distancia entre los puntos (5, 5) y (0, 0) es 7.0710678118654755
# La distancia entre los puntos (-3, -1) y (0, 0) es 3.1622776601683795
# La base del rectángulo es 3
# La altura del rectángulo es 2
# El área del rectángulo es 6

# %% [markdown]
# # Ejercicio 7

# %% [markdown]
# #### Creación
#
# Trabajemeos con herencia.
#
# * Crea una clase llamada __Vehiculo__ que tenga los atributos: color y ruedas
# * Crea el __constructor__ de la clase.
# * Sobreescribe el método **string (``__str__``)**, para que al imprimir por pantalla un vehículo veamos su información
# * Crea una clase que se llame __Coche que herede de Vehiculo__
# * Crear el __constructor__ de la clase, que incluya todo lo del constructor de Vehiculo más velocidad y cilindrada.
# * Sobreescribe el método **string (``__str__``)**, para que al imprimir por pantalla un coche veamos su información
#
# <img src="./Herencia1.png"  />
#
# #### Experimentación
#
# * Crea algunos coches y mostrar su información

# %%
# Realizar el ejercicio aquí
class vehiculo:

    def __init__(self,nombre,color,rueda):
        self.nombre=nombre
        self.color=color
        self.rueda=rueda
        
    def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}""".format(self.nombre,self.color,self.rueda)



class coche(vehiculo):
     velocidad=0
     cilindrada=0
     def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}
       velocidad(kmh):\t{}
       cilindrada(cc):\t{}""".format(self.nombre,self.color,self.rueda,self.velocidad,self.cilindrada)


v2=coche('renault','rojo',4)
v2.cilindrada=100
v2.velocidad=120
print(v2)
# Out:
#        nombre:	renault
#        color:	rojo
#        rueda:	4
#        velocidad(kmh):	120
#        cilindrada(cc):	100

# %% [markdown]
# # Ejercicio 8

# %% [markdown]
# #### Creación
#
# Trabajemos con herencia. Sigamos ampliando el ejercicio anterior.
# Copia todo el código que ya tengas y añade lo siguiente:
#
# * Crear las __clases heredadas__ de Vehiculo que aparecen en la imagen
# * Crea los __constructores__ para esas clases.
# * Sobreescribe los métodos **string (``__str__``)**, para que al imprimir por pantalla se vea la información correspondiente.
# * Crear una __lista__ y dentro de ella introducir __al menos un objeto de cada subclase__ de Vehiculo
# * Realiza una función llamada __catalogar()__ que reciba la lista de vehiculos y los recorra mostrando el nombre de su clase y sus atributos.
# * Modifica la función __catalogar()__ para que reciba un argumento optativo ruedas, haciendo que muestre únicamente los que su número de ruedas concuerde con el valor del argumento. También debe mostrar un mensaje "Se han encontrado {} vehículos con {} ruedas:" únicamente si se envía el argumento ruedas. Ponla a prueba con 0, 2 y 4 ruedas como valor.
#
# Pista. Averigua para que sirve esta instrucción y si te va a resultar útil **``type(objeto).__name__``**
#
# <img src="./Herencia2.png"  />
#
# #### Experimentación
#
# * Crea algunos coches y mostrar su información

# %%
# Realizar el ejercicio aquí
class vehiculo:

    def __init__(self,nombre,color,rueda):
        self.nombre=nombre
        self.color=color
        self.rueda=rueda
        lista_nombres.append(self.nombre)
    def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}""".format(self.nombre,self.color,self.rueda)


class bicicleta(vehiculo):
     tipo=""
     def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}
       tipo(urbano o deportivo):\t{}""".format(self.nombre,self.color,self.rueda,self.tipo)

class motocicleta(bicicleta):
     velocidad=0
     cilindrada=0
     def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}
       velocidad(kmh):\t{}
       cilindrada(cc):\t{}
       tipo(urbano o deportivo):\t{}""".format(self.nombre,self.color,self.rueda,self.velocidad,self.cilindrada,self.tipo)    

class coche(vehiculo):
     velocidad=0
     cilindrada=0
     def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}
       velocidad(kmh):\t{}
       cilindrada(cc):\t{}""".format(self.nombre,self.color,self.rueda,self.velocidad,self.cilindrada)

class camioneta(coche):
     carga=0
     def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}
       velocidad(kmh):\t{}
       cilindrada(cc):\t{}
       carga(kg):{}""".format(self.nombre,self.color,self.rueda,self.velocidad,self.cilindrada,self.carga)


def catalogar(ruedas):
    global lista_nombres
    if ruedas!=0:
        for i in lista_nombres:
            if  eval(i).rueda!=ruedas:
              lista_nombres.remove(i)
    
    
    
    for i in lista_nombres:
        print('clase es:'+type(eval(i)).__name__)
        print(eval(i))
      
        


lista_nombres=[]  
focus=coche('focus','rojo',4)
electrica=bicicleta('electrica','roja',2)
catalogar(2)
# Out:
# clase es:bicicleta
#
#        nombre:	electrica
#        color:	roja
#        rueda:	2
#        tipo(urbano o deportivo):

# %% [markdown]
# # Ejercicio 9

# %% [markdown]
# #### Creación
#
# Trabajemos con herencia. Sigamos ampliando el ejercicio anterior.
# Copia todo el código que ya tengas y añade lo siguiente:
#
# * Un método que se llame **filtrar** que reciba 2 parámetros, la lista de vehículos y el nombre de uno de los tipos de vehículos, para poder filtrar en la lista, es decir, __Coche, Camioneta, etc.__. El método debe recorrer la lista, encontrar las coincidencias y guardarlas en una lista nueva. Esta nueva lista se debe devolver al programa principal donde se recorrerá y mostrará su contenido. La llamada en el programa principal deberá ser así: **``listaCoches = filtrar(lista, "Coche")``**
#
# #### Experimentación
#
# * Crea algunos vehículos (más de uno por tipo)
# * Filtra por los diferentes tipos de Vehiculo y muestra los resultados retornados

# %%
# Realizar el ejercicio aquí

class vehiculo:

    def __init__(self,nombre,color,rueda):
        self.nombre=nombre
        self.color=color
        self.rueda=rueda
        lista_nombres.append(self.nombre)
    def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}""".format(self.nombre,self.color,self.rueda)


class bicicleta(vehiculo):
     tipo=""
     def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}
       tipo(urbano o deportivo):\t{}""".format(self.nombre,self.color,self.rueda,self.tipo)

class motocicleta(bicicleta):
     velocidad=0
     cilindrada=0
     def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}
       velocidad(kmh):\t{}
       cilindrada(cc):\t{}
       tipo(urbano o deportivo):\t{}""".format(self.nombre,self.color,self.rueda,self.velocidad,self.cilindrada,self.tipo)    

class coche(vehiculo):
     velocidad=0
     cilindrada=0
     def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}
       velocidad(kmh):\t{}
       cilindrada(cc):\t{}""".format(self.nombre,self.color,self.rueda,self.velocidad,self.cilindrada)

class camioneta(coche):
     carga=0
     def __str__(self):
       return"""\t
       nombre:\t{}
       color:\t{}
       rueda:\t{}
       velocidad(kmh):\t{}
       cilindrada(cc):\t{}
       carga(kg):{}""".format(self.nombre,self.color,self.rueda,self.velocidad,self.cilindrada,self.carga)

class filtrar():
    def __init__(self,lista_nombres,filtrado):
      self.filtrado=filtrado
      self.lista_nombres=lista_nombres

      for i in lista_nombres:
          if type(eval(i)).__name__==filtrado:
                lista_filtrada.append(i)

    


def catalogar(lista_nombres,ruedas):
    
    if ruedas!=0:
        for i in lista_nombres:
            if  eval(i).rueda!=ruedas:
              lista_nombres.remove(i)
    
    
    for i in lista_nombres:
            print('clase es:'+type(eval(i)).__name__)
            print(eval(i))
      
        

lista_filtrada=[]
lista_nombres=[]

focus=coche('focus','rojo',4)
renault=coche('renault','verde',4)
electrica=bicicleta('electrica','roja',2)
listaCoches = filtrar(lista_nombres, "coche") 
catalogar(lista_nombres,0)
print("")
print("")
print("empieza el catalogo filtrado")
print("")
catalogar(lista_filtrada,0)
# Out:
# clase es:coche
#
#        nombre:	focus
#        color:	rojo
#        rueda:	4
#        velocidad(kmh):	0
#        cilindrada(cc):	0
# clase es:coche
#
#        nombre:	renault
#        color:	verde
#        rueda:	4
#        velocidad(kmh):	0
#        cilindrada(cc):	0
# clase es:bicicleta
#
#        nombre:	electrica
#        color:	roja
#        rueda:	2
#        tipo(urbano o deportivo):
#
#
# empieza el catalogo filtrado
#
# clase es:coche
#
#        nombre:	focus
#        color:	rojo
#        rueda:	4
#        velocidad(kmh):	0
#        cilindrada(cc):	0
# clase es:coche
#
#        nombre:	renault
#        color:	verde
#        rueda:	4
#        velocidad(kmh):	0
#        cilindrada(cc):	0
